# %% [markdown]
# # Tune GPT2 to generate positive reviews
# > Optimise GPT2 to produce positive IMDB movie reviews using a BERT sentiment classifier as a reward function.

# %% [markdown]
# <div style="text-align: center">
# <img src='https://huggingface.co/datasets/trl-internal-testing/example-images/resolve/main/images/gpt2_bert_training.png' width='600'>
# <p style="text-align: center;"> <b>Figure:</b> Experiment setup to tune GPT2. The yellow arrows are outside the scope of this notebook, but the trained models are available through Hugging Face. </p>
# </div>
#
#
# In this notebook we fine-tune GPT2 (small) to generate positive movie reviews based on the IMDB dataset. The model gets the start of a real review and is tasked to produce positive continuations. To reward positive continuations we use a BERT classifier to analyse the sentiment of the produced sentences and use the classifier's outputs as rewards signals for PPO training.

# %% [markdown]
# ## Setup experiment

# %% [markdown]
# ### Import dependencies

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %pip install transformers trl wandb
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.38.2)
# Collecting trl
#   Downloading trl-0.7.11-py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 2.6 MB/s eta 0:00:00
# Collecting wandb
#   Downloading wandb-0.16.4-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 52.4 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from trl) (2.2.1+cu121)
# Collecting accelerate (from trl)
#   Downloading accelerate-0.28.0-py3-none-any.whl (290 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 14.2 MB/s eta 0:00:00
# Collecting datasets (from trl)
#   Downloading datasets-2.18.0-py3-none-any.whl (510 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 25.7 MB/s eta 0:00:00
# Collecting tyro>=0.5.11 (from trl)
#   Downloading tyro-0.7.3-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb) (8.1.7)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb)
#   Downloading GitPython-3.1.42-py3-none-any.whl (195 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 14.3 MB/s eta 0:00:00
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (5.9.5)
# Collecting sentry-sdk>=1.0.0 (from wandb)
#   Downloading sentry_sdk-1.42.0-py2.py3-none-any.whl (263 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 263.5/263.5 kB 27.9 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting setproctitle (from wandb)
#   Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb) (67.7.2)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl) (3.1.3)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.4.0->trl)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 53.2 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.4.0->trl)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 58.1 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.4.0->trl)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 80.1 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.4.0->trl)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.0 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.4.0->trl)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.4 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.4.0->trl)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.4 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.4.0->trl)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 13.7 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.4.0->trl)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.6 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.4.0->trl)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 2.4 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.4.0->trl)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.9 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.4.0->trl)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 13.5 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.4.0->trl)
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 63.6 MB/s eta 0:00:00
# Collecting docstring-parser>=0.14.1 (from tyro>=0.5.11->trl)
#   Downloading docstring_parser-0.15-py3-none-any.whl (36 kB)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.10/dist-packages (from tyro>=0.5.11->trl) (13.7.1)
# Collecting shtab>=1.5.6 (from tyro>=0.5.11->trl)
#   Downloading shtab-1.7.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->trl) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets->trl) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->trl)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 12.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->trl) (1.5.3)
# Collecting xxhash (from datasets->trl)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 23.6 MB/s eta 0:00:00
# Collecting multiprocess (from datasets->trl)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 16.2 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->trl) (3.9.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->trl) (4.0.3)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (2.16.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.4.0->trl) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->trl) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->trl) (2023.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.4.0->trl) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl) (0.1.2)
# Installing collected packages: xxhash, smmap, shtab, setproctitle, sentry-sdk, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, docstring-parser, docker-pycreds, dill, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, gitdb, tyro, nvidia-cusolver-cu12, GitPython, wandb, datasets, accelerate, trl
# Successfully installed GitPython-3.1.42 accelerate-0.28.0 datasets-2.18.0 dill-0.3.8 docker-pycreds-0.4.0 docstring-parser-0.15 gitdb-4.0.11 multiprocess-0.70.16 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105 sentry-sdk-1.42.0 setproctitle-1.3.3 shtab-1.7.1 smmap-5.0.1 trl-0.7.11 tyro-0.7.3 wandb-0.16.4 xxhash-3.4.1

# %%
import torch
from tqdm import tqdm
import pandas as pd

tqdm.pandas()

from transformers import pipeline, AutoTokenizer
from datasets import load_dataset

from trl import PPOTrainer, PPOConfig, AutoModelForCausalLMWithValueHead
from trl.core import LengthSampler

# %% [markdown]
# ### Configuration

# %%
config = PPOConfig(
    model_name="lvwerra/gpt2-imdb",
    learning_rate=1.41e-5,
    log_with="wandb",
)

sent_kwargs = {"return_all_scores": True, "function_to_apply": "none", "batch_size": 16}

# %%
import wandb

wandb.init()

# %% [markdown]
# You can see that we load a GPT2 model called `gpt2_imdb`. This model was additionally fine-tuned on the IMDB dataset for 1 epoch with the huggingface [script](https://github.com/huggingface/transformers/blob/master/examples/run_language_modeling.py) (no special settings). The other parameters are mostly taken from the original paper ["Fine-Tuning Language Models from Human Preferences"](
# https://arxiv.org/pdf/1909.08593.pdf). This model as well as the BERT model is available in the Huggingface model zoo [here](https://huggingface.co/models). The following code should automatically download the models.

# %% [markdown]
# ## Load data and models

# %% [markdown]
# ### Load IMDB dataset
# The IMDB dataset contains 50k movie review annotated with "positive"/"negative" feedback indicating the sentiment.  We load the IMDB dataset into a DataFrame and filter for comments that are at least 200 characters. Then we tokenize each text and cut it to random size with the `LengthSampler`.

# %%
def build_dataset(config, dataset_name="imdb", input_min_text_length=2, input_max_text_length=8):
    """
    Build dataset for training. This builds the dataset from `load_dataset`, one should
    customize this function to train the model on its own dataset.

    Args:
        dataset_name (`str`):
            The name of the dataset to be loaded.

    Returns:
        dataloader (`torch.utils.data.DataLoader`):
            The dataloader for the dataset.
    """
    tokenizer = AutoTokenizer.from_pretrained(config.model_name)
    tokenizer.pad_token = tokenizer.eos_token
    # load imdb with datasets
    ds = load_dataset(dataset_name, split="train")
    ds = ds.rename_columns({"text": "review"})
    ds = ds.filter(lambda x: len(x["review"]) > 200, batched=False)

    input_size = LengthSampler(input_min_text_length, input_max_text_length)

    def tokenize(sample):
        sample["input_ids"] = tokenizer.encode(sample["review"])[: input_size()]
        sample["query"] = tokenizer.decode(sample["input_ids"])
        return sample

    ds = ds.map(tokenize, batched=False)
    ds.set_format(type="torch")

    return ds

# %%
imdb_dataset = load_dataset("imdb", split="train")

df = pd.DataFrame(imdb_dataset)
df
# Out:
#                                                     text  label
# 0      I rented I AM CURIOUS-YELLOW from my video sto...      0
# 1      "I Am Curious: Yellow" is a risible and preten...      0
# 2      If only to avoid making this type of film in t...      0
# 3      This film was probably inspired by Godard's Ma...      0
# 4      Oh, brother...after hearing about this ridicul...      0
# ...                                                  ...    ...
# 24995  A hit at the time but now better categorised a...      1
# 24996  I love this movie like no other. Another time ...      1
# 24997  This film and it's sequel Barry Mckenzie holds...      1
# 24998  'The Adventures Of Barry McKenzie' started lif...      1
# 24999  The story centers around Barry McKenzie who mu...      1
#
# [25000 rows x 2 columns]

# %%
dataset = build_dataset(config)


def collator(data):
    return dict((key, [d[key] for d in data]) for key in data[0])
# Out:
# Dataset({
#     features: ['review', 'label', 'input_ids', 'query'],
#     num_rows: 24895
# })

# %% [markdown]
# ### Load pre-trained GPT2 language models

# %% [markdown]
# We load the GPT2 model with a value head and the tokenizer. We load the model twice; the first model is optimized while the second model serves as a reference to calculate the KL-divergence from the starting point. This serves as an additional reward signal in the PPO training to make sure the optimized model does not deviate too much from the original language model.

# %%
import torch
import numpy as np
import transformers
from tqdm import tqdm
from torch.utils.data import Dataset, DataLoader
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# %%
model = AutoModelForCausalLMWithValueHead.from_pretrained(config.model_name)
ref_model = AutoModelForCausalLMWithValueHead.from_pretrained(config.model_name)
tokenizer = AutoTokenizer.from_pretrained(config.model_name)

tokenizer.pad_token = tokenizer.eos_token

# %%
texts = [
    "Александр Сергеевич Пушкин родился в ",
    "Alexander Sergeevich Pushkin was born in ",
    "Олександр Сергійович Пушкін народився в ",
    "Аляксандр Сяргеевіч Пушкін нарадзіўся ў ",
    "Александр Сергеевич Пушкин шәһәрендә туган",
    "Александр Сергеевич Пушкин дүниеге келген",
    "亚历山大*谢尔盖耶维奇*普希金出生于",
    "알렉산더 세르게 비치 푸쉬킨은 ",
    "Alexander Sergeevich Pushkinはで生まれました",
    "Александр Сергеевич Пушкин ҫуралнӑ ",
    "Александр Сергеевич Пушкин төрөөбүтэ ",
    "Alexander Puschkin wurde in ",
    "Alexandre Sergueïevitch Pouchkine est né le à ",
]

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()
transformers.set_seed(1337)

for text in texts:
    input_ids = tokenizer.encode(text, return_tensors="pt").to(device)
    out = model.generate(
        input_ids,
        min_length=100,
        max_length=100,
        eos_token_id=5,
        do_sample=True,
        top_k=0,
        top_p=0.9,
        no_repeat_ngram_size=4)
    generated_text = list(map(tokenizer.decode, out))[0]
    print('---')
    print(generated_text)
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:5 for open-end generation.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:5 for open-end generation.
# ---
# Александр Сергеевич Пушкин родился в самях сво ском сумя струсских / ᗑ талы ститрта! <br /><br />Anyway, before you
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:5 for open-end generation.
# ---
# Alexander Sergeevich Pushkin was born in vernacular Czechoslovakia in 1913, and only later came to Czechoslovakia where he lived for more than 30 years, joining forces with former Soviet Union president Joseph Stalin. Polanski's career proceeded with a certain amount of honesty, and many of his films were certainly well-known. The art and film quality of the plot were excellent. The director was never too keen on keeping the story simple and non-linear, and definitely not underhanded
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:5 for open-end generation.
# ---
# Олександр Сергійович Пушкін народився в сохсте Бтильсть іомистсяж, іятлявлянтостия) etc. Also the self-
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:5 for open-end generation.
# ---
# Аляксандр Сяргеевіч Пушкін нарадзіўся ў стрерг. Also note the bizarre and unbelievable appearance of the girls from the film as a fairy tale. It is also found that the author himself was convicted in the following court proceedings. The characters are mostly non-english speaking
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:5 for open-end generation.
# ---
# Александр Сергеевич Пушкин шәһәрендә туган.
#
# The production "Dream" has three separate figures and their own unique costumes that use whatever uniform that they choose, which it is in at least the first half of the movie.<br /><br />This movie is a British
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:5 for open-end generation.
# ---
# Александр Сергеевич Пушкин дүниеге келгеной/олюрыл? (Indisputably true)<|endoftext|> Fictionalized and unique take on the final stand during WWII in West Germany, not to mention an expansive selection of classic Soviet movies. While the story is ostensibly a
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:5 for open-end generation.
# ---
# 亚历山大*谢尔盖耶维奇*普希金出生于不过* 取化国上海洖发已店击伙慙绝* 伙给<..........‍ <br /><br />The director does not only make very simple and inexpensive films, he
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:5 for open-end generation.
# ---
# 알렉산더 세르게 비치 푸쉬킨은 가 아떅경꽑털해 크떨로 어것 하늘어 햄엀 업어은
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:5 for open-end generation.
# ---
# Alexander Sergeevich Pushkinはで生まれましたも???<|endoftext|> Should be a great movie for all ages. Beautiful settings, complex characters, great screenplay, superb photography. Unfortunately the next 4 or 5 minutes of this movie will NOT set you back a dollar. Don't waste your time on this non existent movie.<|endoftext|> First of all...this movie is NOT even good. It looks REALLY like a funny comic book with almost no comic structure whatsoever.<br /><br />
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:5 for open-end generation.
# ---
# Александр Сергеевич Пушкин ҫуралнӑ ҙҝҖҜÖ <br /><br />End Notes: King Michael Porter: What St George teaches is deep...<br /><Br />Anton Polson: Benjamin Grimm, Anah Eng, Philip Cotten, Julia Adagai,
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:5 for open-end generation.
# ---
# Александр Сергеевич Пушкин төрөөбүтэ тр рәрсҗҗу ттр сур трәыҙ хвр улож трыхем тр Бл
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:5 for open-end generation.
# ---
# Alexander Puschkin wurde in urn is an educational movie. But Michael Caine's Travolta seems to have potential. He's not dumb like his character, nor he was too dumb to act. He's a great actor who's leaving the theater early, like he's walking around in Halloween costumes as a 'cool' guy doing a couple of stand-up specials.<br /><br />Moleaville Goodnight and Laurence Olivier gave very well performances
# ---
# Alexandre Sergueïevitch Pouchkine est né le à été directement, la graphèle ou bleu d'atrava et que n'état pas femmes-Toulouse. Comme aller ce verêtes par les cannonades classe et a travail en GhastlyMouton, est-Vincent Abbot, recevaluer en vie le mère, les advances on JouroSemann

# %% [markdown]
# ### Initialize PPOTrainer
# The `PPOTrainer` takes care of device placement and optimization later on:

# %%
ppo_trainer = PPOTrainer(config, model, ref_model, tokenizer, dataset=dataset, data_collator=collator)
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.16.4
# Run data is saved locally in <code>/content/wandb/run-20240314_213816-xusu9kid</code>
# Syncing run <strong><a href='https://wandb.ai/ytu-bitirme/trl/runs/xusu9kid' target="_blank">blackberry-brownie-11</a></strong> to <a href='https://wandb.ai/ytu-bitirme/trl' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ytu-bitirme/trl' target="_blank">https://wandb.ai/ytu-bitirme/trl</a>
#  View run at <a href='https://wandb.ai/ytu-bitirme/trl/runs/xusu9kid' target="_blank">https://wandb.ai/ytu-bitirme/trl/runs/xusu9kid</a>

# %% [markdown]
# ### Load BERT classifier
# We load a BERT classifier fine-tuned on the IMDB dataset.

# %%
device = ppo_trainer.accelerator.device
if ppo_trainer.accelerator.num_processes == 1:
    device = 0 if torch.cuda.is_available() else "cpu"  # to avoid a `pipeline` bug
sentiment_pipe = pipeline("sentiment-analysis", model="lvwerra/distilbert-imdb", device=device)
# Out:
# config.json:   0%|          | 0.00/735 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/333 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %% [markdown]
# The model outputs are the logits for the negative and positive class. We will use the logits for positive class as a reward signal for the language model.

# %%
text = "this movie was really bad!!"
sentiment_pipe(text, **sent_kwargs)
# Out:
# [[{'label': 'NEGATIVE', 'score': 2.335048198699951},
#   {'label': 'POSITIVE', 'score': -2.726576328277588}]]

# %%
text = "this movie was really good!!"
sentiment_pipe(text, **sent_kwargs)
# Out:
# [[{'label': 'NEGATIVE', 'score': -2.2947897911071777},
#   {'label': 'POSITIVE', 'score': 2.557039737701416}]]

# %% [markdown]
# ### Generation settings
# For the response generation we just use sampling and make sure top-k and nucleus sampling are turned off as well as a minimal length.

# %%
gen_kwargs = {"min_length": -1, "top_k": 0.0, "top_p": 1.0, "do_sample": True, "pad_token_id": tokenizer.eos_token_id}

# %% [markdown]
# ## Optimize model

# %% [markdown]
# ### Training loop

# %% [markdown]
# The training loop consists of the following main steps:
# 1. Get the query responses from the policy network (GPT-2)
# 2. Get sentiments for query/responses from BERT
# 3. Optimize policy with PPO using the (query, response, reward) triplet
#
# **Training time**
#
# This step takes **~2h** on a V100 GPU with the above specified settings.

# %%
output_min_length = 4
output_max_length = 16
output_length_sampler = LengthSampler(output_min_length, output_max_length)


generation_kwargs = {
    "min_length": -1,
    "top_k": 0.0,
    "top_p": 1.0,
    "do_sample": True,
    "pad_token_id": tokenizer.eos_token_id,
}


for epoch, batch in tqdm(enumerate(ppo_trainer.dataloader)):
    query_tensors = batch["input_ids"]

    #### Get response from gpt2
    response_tensors = []
    for query in query_tensors:
        gen_len = output_length_sampler()
        generation_kwargs["max_new_tokens"] = gen_len
        response = ppo_trainer.generate(query, **generation_kwargs)
        response_tensors.append(response.squeeze()[-gen_len:])
    batch["response"] = [tokenizer.decode(r.squeeze()) for r in response_tensors]

    #### Compute sentiment score
    texts = [q + r for q, r in zip(batch["query"], batch["response"])]
    pipe_outputs = sentiment_pipe(texts, **sent_kwargs)
    rewards = [torch.tensor(output[1]["score"]) for output in pipe_outputs]

    #### Run PPO step
    stats = ppo_trainer.step(query_tensors, response_tensors, rewards)
    ppo_trainer.log_stats(stats, batch, rewards)
# Out:
# 0it [00:00, ?it/s]You're using a GPT2TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (11.45) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (10.90) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (60.35) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (11.79) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (60.87) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (26.74) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 1it [01:42, 102.95s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (89.16) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (10.91) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (284.66) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (25.76) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (64.38) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (21.85) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (17.21) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (27.70) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (19.99) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (138.24) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (11.44) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (2321.48) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (24.24) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (28.71) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (27.99) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (26.83) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (11.00) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (26.07) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (16.55) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (84.53) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (10.80) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (17.43) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (15.87) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (29.25) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (284.27) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (158.29) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (12.77) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (59.06) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (97.08) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (25.95) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (45.62) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (1844.53) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (10.55) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (22.15) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (22.39) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (26.92) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (10.33) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (23.20) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (82.67) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (14.78) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (1777.16) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (148.94) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (28.21) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (29.04) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (16.57) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (22.57) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (46.24) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (25.51) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (16.02) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (10.26) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (101.50) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (29.96) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (284.41) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (59.07) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 2it [03:26, 103.41s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (16.90) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (10.95) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (19.45) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (49.50) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (54.32) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (70.29) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (181.98) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (10.56) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (15.94) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (30.71) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (764.00) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (56.99) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (42.17) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (10.86) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (26.02) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (303.63) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (15.79) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (11.43) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (64.32) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (760.25) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (15.13) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (18.31) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (43.65) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (22.54) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (58.58) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (26.32) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (11.71) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (314.89) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (60.39) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (11.89) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (16.28) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 3it [05:13, 104.95s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (14.17) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (50.49) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (172.81) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (58.71) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (12.76) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (399.34) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (19.61) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (399.44) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (23.27) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (61.88) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (13.25) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (12.22) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (61.51) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (164.81) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (33.59) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (10.94) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (24.20) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (12.13) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (11.15) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (164.52) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (61.59) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (62.75) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (32.80) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (401.77) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (13.12) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 4it [06:59, 105.49s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (8014.02) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (12.15) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (22.95) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (14.02) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (23.52) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (28.11) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (1247.28) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (25.17) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (40.20) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (22.62) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (5008.65) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (24.16) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (3206.75) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (5017.52) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (7849.59) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (10.83) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (26.93) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (36.48) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (23.55) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (11.25) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (25.27) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (14.03) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (1334.12) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (24.91) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (24.36) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (41.42) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (5253.70) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (11.12) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (2937.99) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (20.97) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (1418.13) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (11.18) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (24.69) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (23.11) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (7821.04) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (13.99) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 5it [08:44, 105.18s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (646.69) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (40.21) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (217.23) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (26.62) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (21.06) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (39.38) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (39.81) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (15.24) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (217.56) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (39.56) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (21.66) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (27.12) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (629.71) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (16.73) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (10.05) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (659.24) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (28.77) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (39.06) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (37.82) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (217.71) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (10.71) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 6it [10:30, 105.60s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (48.81) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (15.68) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (21288.79) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (44.86) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (22.18) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (10.93) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (21.57) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (12.39) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (52.58) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (18.29) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (24953.80) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (43.75) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (24413.10) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (14.15) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (21.53) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (11.19) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (51.12) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (44.36) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (17.41) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 7it [12:14, 105.06s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (97.59) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (73.06) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (400.45) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (14.60) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (72.86) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (55.68) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (11.80) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (11.28) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (291.89) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (63.95) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (73.71) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (10.48) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (400.21) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (81.29) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (73.10) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (12.68) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (14.70) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (53.11) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (10.58) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (13.33) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (52.06) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (13.14) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (76.11) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (250.16) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (400.90) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (12.34) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (12.63) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (11.34) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (14.69) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (10.23) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (67.80) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (86.35) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (73.41) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 8it [13:59, 104.90s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (15.34) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (28.61) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (227.37) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (133.09) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (35.28) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (31.18) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (14.77) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (244.60) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (22.64) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (1430.32) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (18.63) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (11.01) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (131.77) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (1430.28) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (32.05) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (30.60) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (17.01) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (259.27) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (18.98) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (36.26) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (213.23) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (16.91) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (1430.30) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (20.31) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (36.00) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (246.12) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (25.53) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (36.03) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (15.25) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (236.66) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (158.97) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (27.15) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 9it [15:43, 104.83s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (46.18) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (64.83) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (17.96) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (64.97) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (16.71) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (12.98) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (15.51) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (15.70) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# ...
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (183.25) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (28.82) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (29.18) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (1322.29) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (32.69) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (42.67) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (28.83) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (187.01) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (14.50) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (1487.38) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (219.14) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (247.13) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (29.97) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (1121.59) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (157.98) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (477.22) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (65.88) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 93it [2:40:06, 100.54s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (24.23) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (126.89) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (72.35) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (172.17) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (55.90) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (54.61) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (72.79) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (170.48) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (57.89) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (1262.78) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (29.26) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (125.63) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (122.24) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (69.58) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (173.69) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (58.18) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (70.95) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (1274.27) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 94it [2:41:49, 101.11s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (57.86) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (22.71) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (20.89) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (30.27) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (45.77) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (24.50) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (18.76) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (53.98) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (3296.28) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (27.20) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (30.55) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (18.02) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (26.53) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (43.47) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (45.69) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (17.17) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (3295.92) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (17.26) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (20.86) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (56.17) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (45.74) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (20.94) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (27.42) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (3295.69) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (23.18) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (56.92) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (17.38) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (30.86) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 95it [2:43:31, 101.50s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (119.12) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (14.73) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (13.71) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (11.60) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (103.15) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (118.92) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (36.39) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (124.33) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (11.86) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (104.17) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (16.32) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 96it [2:45:13, 101.67s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (35.23) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (48.46) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (2869.60) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (26.55) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (2664.58) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (14.68) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (27.84) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (54.45) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (12.97) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (61.29) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (2660.79) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (12.80) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (28.07) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1174: UserWarning: The average ratio of batch (52.96) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 97it [2:46:56, 103.26s/it]

# %% [markdown]
# ### Training progress
# If you are tracking the training progress with Weights&Biases you should see a plot similar to the one below. Check out the interactive sample report on wandb.ai: [link](https://app.wandb.ai/huggingface/trl-showcase/runs/1jtvxb1m/).
#
# <div style="text-align: center">
# <img src='https://huggingface.co/datasets/trl-internal-testing/example-images/resolve/main/images/gpt2_tuning_progress.png' width='800'>
# <p style="text-align: center;"> <b>Figure:</b> Reward mean and distribution evolution during training. </p>
# </div>
#
# One can observe how the model starts to generate more positive outputs after a few optimisation steps.
#
# > Note: Investigating the KL-divergence will probably show that at this point the model has not converged to the target KL-divergence, yet. To get there would require longer training or starting with a higher initial coefficient.

# %% [markdown]
# ## Model inspection
# Let's inspect some examples from the IMDB dataset. We can use `model_ref` to compare the tuned model `model` against the model before optimisation.

# %%
#### get a batch from the dataset
bs = 16
game_data = dict()
dataset.set_format("pandas")
df_batch = dataset[:].sample(bs)
game_data["query"] = df_batch["query"].tolist()
query_tensors = df_batch["input_ids"].tolist()

response_tensors_ref, response_tensors = [], []

#### get response from gpt2 and gpt2_ref
for i in range(bs):
    gen_len = output_length_sampler()
    output = ref_model.generate(
        torch.tensor(query_tensors[i]).unsqueeze(dim=0).to(device), max_new_tokens=gen_len, **gen_kwargs
    ).squeeze()[-gen_len:]
    response_tensors_ref.append(output)
    output = model.generate(
        torch.tensor(query_tensors[i]).unsqueeze(dim=0).to(device), max_new_tokens=gen_len, **gen_kwargs
    ).squeeze()[-gen_len:]
    response_tensors.append(output)

#### decode responses
game_data["response (before)"] = [tokenizer.decode(response_tensors_ref[i]) for i in range(bs)]
game_data["response (after)"] = [tokenizer.decode(response_tensors[i]) for i in range(bs)]

#### sentiment analysis of query/response pairs before/after
texts = [q + r for q, r in zip(game_data["query"], game_data["response (before)"])]
game_data["rewards (before)"] = [output[1]["score"] for output in sentiment_pipe(texts, **sent_kwargs)]

texts = [q + r for q, r in zip(game_data["query"], game_data["response (after)"])]
game_data["rewards (after)"] = [output[1]["score"] for output in sentiment_pipe(texts, **sent_kwargs)]

# store results in a dataframe
df_results = pd.DataFrame(game_data)
df_results
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_classification.py:105: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
#                                       query  \
# 0                  When originally screened
# 1                           Born Again is a
# 2          Generally speaking, the plot was
# 3                    I have seen the recent
# 4                              Description:
# 5                       Director Edward Sed
# 6                       Robert Siodmak does
# 7                                    DO NOT
# 8                                  Where to
# 9                         STAR RATING: ****
# 10                    I became a fan of the
# 11           This is a very old and cheaply
# 12                               **SPOILERS
# 13                       Mirage (1990) is a
# 14                                  Vampire
# 15  Yet another forgettable Warners foreign
#
#                                     response (before)  \
# 0                                      on May 6, 1986
# 1    great movie. It's not without faults, but the...
# 2            ...well...plain and simple. Warriors (or
# 3    revelation that Italian detonator peppers die...
# 4                         Servant (Iraq)2 Fight chore
# 5              gwick (mostly) at Vancouver Studios. I
# 6    a good job as a character who has little conn...
# 7                           SLOW THE WAY BACK WHEN UR
# 8    see it?'' Michael Devito directed and starred...
# 9   STAR RATING: ****- ****+. *1 out of 5 stars<|e...
# 10                                   show 2 years ago
# 11   made film about spoofs - with ten aborted jok...
# 12                     **SPOILERS AHEAD!<|endoftext|>
# 13                     spectacular, short-lived piece
# 14   Diaries" itself from being scripted into a lo...
# 15   taxes filler film that isn't even near overhe...
#
#                                      response (after)  rewards (before)  \
# 0                                  this film in 1975,          0.523658
# 1      very good film. I've seen it many times and it          2.775483
# 2              great and I liked it! I enjoyed it and          0.610508
# 3                 movie, and I really enjoyed it. The          0.933963
# 4    This film is incredible with extraordinary ch...         -1.317536
# 5           ol himself has his hat on, the best event         -0.269634
# 6                well, and I see him again. I see him          0.688905
# 7          self hide beautiful animation on your body          0.493870
# 8    bad CGI? Reality, I love things. I think, pri...         -2.026147
# 9   * Those engaged in a settlement in war. DIRECT...          0.625100
# 10                             show many years before          1.513936
# 11   produced animation with a very mediocre plot ...         -2.576891
# 12  , I love this movie! It is truly an enjoyable ...         -0.266715
# 13                         stunning white-cloth film,          2.367067
# 14   is a great of a film w... hands-holding toget...         -2.870511
# 15     film; André Edwards is already one of the best         -2.857510
#
#     rewards (after)
# 0          0.912804
# 1          2.817165
# 2          2.824210
# 3          2.766923
# 4          2.904070
# 5          2.058803
# 6          2.249197
# 7          2.015016
# 8          1.625459
# 9          1.671162
# 10         1.782018
# 11         1.302560
# 12         2.855858
# 13         2.397995
# 14         2.623672
# 15        -2.083694
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_0, *['index'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_1, *['rewards (before)'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_2, *['rewards (after)'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plot(df, x_colname, y_colname, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(6 * figscale, 6 * figscale))
#   df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha)
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plot(_df_3, *['index', 'rewards (before)'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plot(df, x_colname, y_colname, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(6 * figscale, 6 * figscale))
#   df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha)
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plot(_df_4, *['rewards (before)', 'rewards (after)'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_5, *['index', 'rewards (before)', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_6, *['index', 'rewards (after)', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_7, *['index', 'count()', None], **{})
# chart
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_8, *['index'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_9, *['rewards (before)'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_10, *['rewards (after)'], **{})
# chart

# %% [markdown]
# Looking at the reward mean/median of the generated sequences we observe a significant difference.

# %%
print("mean:")
display(df_results[["rewards (before)", "rewards (after)"]].mean())
print()
print("median:")
display(df_results[["rewards (before)", "rewards (after)"]].median())
# Out:
# mean:
# rewards (before)   -0.103278
# rewards (after)     1.920201
# dtype: float64
# median:
# rewards (before)    0.508764
# rewards (after)     2.154000
# dtype: float64

# %% [markdown]
# ## Save model
# Finally, we save the model and push it to the Hugging Face for later usage.
